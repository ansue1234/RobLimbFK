# %% [markdown]
# # Data Processing for Safe RL

# %%
import pandas as pd
import numpy as np

# %%
x_limit = 80
y_limit = 80

# %%
data_1 = pd.read_csv('../ml_data/train_data.csv')
data_2 = pd.read_csv('../ml_data/test_data.csv')
data = pd.concat([data_1, data_2])

# %% [markdown]
# ## Computing rewards
#
# To avoid numbers that are too big, change everything to radians

# %%
data['theta_x'] = np.deg2rad(data['theta_x'])
data['theta_y'] = np.deg2rad(data['theta_y'])

# %%
reward = []
x_limit = np.deg2rad(x_limit)
y_limit = np.deg2rad(y_limit)
D = 0.5*(x_limit**2 + y_limit**2)**0.5
gamma = 0.99
for row_num, row in data.iterrows():
    if row['theta_x'] <= x_limit and row['theta_x'] >= -x_limit and row['theta_y'] <= y_limit and row['theta_y'] >= -y_limit:
        dist_to_bounds_x = min(abs(x_limit - row['theta_x']), abs(-x_limit - row['theta_x']))
        dist_to_bounds_y = min(abs(y_limit - row['theta_y']), abs(-y_limit - row['theta_y']))
        dist_to_bounds = (dist_to_bounds_x**2 + dist_to_bounds_y**2)**0.5
        r = 1 + dist_to_bounds
        reward.append(r)
    else:
        reward.append(-D/(1-gamma))
data['reward'] = reward

# %%
data
# Out:
#        time_begin  time_begin_traj   theta_x   theta_y  vel_x     vel_y  \
# 0           0.358            0.358 -0.086219 -0.187797    0.0  0.000000
# 1           0.421            0.421 -0.086219 -0.187797    0.0  0.000000
# 2           0.485            0.485 -0.086219 -0.187797    0.0  0.000000
# 3           0.548            0.548 -0.086219 -0.187797    0.0  0.000000
# 4           0.612            0.612 -0.086219 -0.187797    0.0  0.000000
# ...           ...              ...       ...       ...    ...       ...
# 31261    1172.517          121.126 -0.384496 -0.656069    0.0  0.000000
# 31262    1172.589          121.198 -0.384496 -0.656069    0.0  0.000000
# 31263    1172.661          121.270 -0.384496 -0.646819    0.0  7.361111
# 31264    1172.733          121.342 -0.384496 -0.646819    0.0  0.000000
# 31265    1172.804          121.413 -0.384496 -0.646819    0.0  0.000000
#
#        X_throttle  Y_throttle    reward
# 0             0.0         0.0  2.782303
# 1             0.0         0.0  2.782303
# 2             0.0         0.0  2.782303
# 3             0.0         0.0  2.782303
# 4             0.0         0.0  2.782303
# ...           ...         ...       ...
# 31261        -2.0        10.0  2.253619
# 31262        -2.0        10.0  2.253619
# 31263        -2.0        10.0  2.259103
# 31264        -2.0        10.0  2.259103
# 31265        -2.0        10.0  2.259103
#
# [143207 rows x 9 columns]

# %%
data.to_csv('../safe_rl_data/data.csv', index=False)

# %%
data.describe()
# Out:
#           time_begin  time_begin_traj        theta_x        theta_y  \
# count  143207.000000    143207.000000  143207.000000  143207.000000
# mean      953.331442        30.882267      -0.006678      -0.000083
# std       674.203298        41.364048       0.793214       0.799035
# min         0.348000         0.348000      -1.813572      -1.816713
# 25%       356.609000         6.497000      -0.570548      -0.551350
# 50%       875.516000        15.390000       0.001047      -0.039444
# 75%      1462.850500        37.159500       0.549953       0.572643
# max      3118.448000       330.651000       1.790533       1.803449
#
#                vel_x          vel_y     X_throttle     Y_throttle  \
# count  143207.000000  143207.000000  143207.000000  143207.000000
# mean        0.368827      -0.152111      -0.123332      -0.028162
# std        16.972159      17.594994       2.173461       2.289834
# min      -165.294118    -151.571429     -10.000000     -10.000000
# 25%       -10.149254     -10.615385      -1.000000      -1.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%        10.298507      10.000000       1.000000       1.000000
# max       121.176471     153.880597      10.000000      10.000000
#
#               reward
# count  143207.000000
# mean      -13.898717
# std        37.005254
# min       -98.730732
# 25%         1.700950
# 50%         2.203503
# 75%         2.489879
# max         2.970174
